# %% [markdown]
# # &AElig;co
# # Visualization Example

# %% [markdown]
# ✈️♻️
#
# This code is part of the Master's Thesis "Streamlined Life Cycle Assessment Method for Aircraft Eco-Design", by Giácomo Parolin.

# %% [markdown]
# ``Please enter the following information:``

# %%
import os
os.chdir("C:/Users/Parolin/Documents/Projects/AEco")

#airbus_path = '.\\Outputs\\A320_outputs_10k'  # LCA results file path
bravo_path = '.\\Outputs\\Bravo_outputs'  # LCA results file path
echo_path = '.\\Outputs\\Echo_outputs'  # LCA results file path

# %%
from Tools import *

# %% [markdown]
# Loading LCA results saved in the `NetCDF` file.

# %%
#airbus = LCIA.load(airbus_path, chunks={}, LCI=False, CTV=True)
bravo = LCIA.load(bravo_path, chunks={}, LCI=False, CTV=True)
echo = LCIA.load(echo_path, chunks={}, LCI=False, CTV=True)

# %% [markdown]
# The distributions of the results, considering all the iterations, are plotted for each impact category using the `LCIA.dist()` method.

# %%
#airbus.dist('MP', save=False)

# %% [markdown]
# Mean midpoint results are shown below.

# %%
#airbus.mean('MP', by='sum').compute()

# %% [markdown]
# Next, we calculate mean midpoint impacts per life cycle phase using the `LCIA.bar()` method.

# %%
#airbus.bar('MP', subphase=True, save=False, palette='deep')

# %%
#airbus.bar('MP', subphase=False, save=False, palette='deep')

# %% [markdown]
# # Endpoint Results

# %% [markdown]
# The distributions of the endpoint results, considering all the iterations, are plotted for each impact category using the `LCIA.dist()` method.

# %%
#airbus.dist('EP', save=False)

# %% [markdown]
# Mean endpoint results are shown below.

# %%
#airbus.mean('EP', by='sum').compute()

# %% [markdown]
# Endpoint impacts per life cycle phase are plotted with the `LCIA.bar()` method.

# %%
#airbus.bar('EP', subphase=True, save=False, palette='deep')

# %%
#airbus.bar('EP', subphase=False, save=False, palette='deep')

# %% [markdown]
# # Single Score Results

# %% [markdown]
# Mean SS results are shown below.

# %%
#airbus.SS("sum").mean('i').compute()

# %% [markdown]
# # CTV Results

# %% [markdown]
# The areas in the following plots represent CTV for each input parameters. Each plot concerns one midpoint or endpoint result. This plot is accessed through the `LCIA.square()` method.

# %%
#airbus.square(save=False)

# %% [markdown]
# # Comparison

# %% [markdown]
# Comparison of two Datasets of LCIA results can be achieved by the `LCIA.compare` method, indicating the desired pathway.
# In this paired comparison method, the iterations of the "Numerator" Dataset are divided by the "Denominator" Dataset, generating a Dataset of ratios.
#
# This new comparison Dataset has the same number of iterations than the original LCIA results Datasets, but, this time, each iteration represents a ratio.
# Ratios less than one mean that the "Numerator" Dataset is advantageous, while ratios greater than one mean that the "Denominator" Dataset is favourable.
# Using this logic, we can have an idea of which aircraft concept has fewer impacts by computing the mean of the iterations, using the `.mean('i')` or `.median('i')` command.

# %%
mistral_mp = echo.compare(bravo, pathway="MP")
mistral_ep = echo.compare(bravo, pathway="EP")

# %%
display(mistral_mp.compute().median('i'))
display(mistral_ep.compute().median('i'))
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     FE       float64 0.982
#     MRD      float64 0.9852
#     POF      float64 0.962
#     MET      float64 0.9875
#     TA       float64 0.9641
#     ULO      float64 0.9757
#     PMF      float64 0.9652
#     TET      float64 0.9657
#     FET      float64 0.9858
#     NLT      float64 0.9793
#     OD       float64 0.9605
#     ME       float64 0.9644
#     ALO      float64 0.9617
#     HT       float64 0.9783
#     IR       float64 0.9601
#     FD       float64 0.9615
#     WD       float64 0.96
#     CC       float64 0.962
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     HH       float64 0.9628
#     ED       float64 0.962
#     RA       float64 0.9616

# %% [markdown]
# All Categories and all AOP have mean results slightly lower than one, meaning the Echo concept is slightly advantageous.
#
# The same point can be proven by using the `comparePercent` function.
# The function shows, in percentage, how many of the iterations are below the threshold of one, meaning how many iterations favour Echo over Bravo.

# %%
display(comparePercent(mistral_mp))
display(comparePercent(mistral_ep))
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     FE       float64 53.75
#     MRD      float64 52.94
#     POF      float64 56.83
#     MET      float64 52.65
#     TA       float64 56.56
#     ULO      float64 55.17
#     PMF      float64 56.46
#     TET      float64 56.68
#     FET      float64 53.01
#     NLT      float64 54.53
#     OD       float64 57.5
#     ME       float64 56.43
#     ALO      float64 57.82
#     HT       float64 54.43
#     IR       float64 57.55
#     FD       float64 57.36
#     WD       float64 56.93
#     CC       float64 56.77
# Attributes:
#     Numerator:    Echo
#     Denominator:  Bravo
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     HH       float64 56.66
#     ED       float64 56.76
#     RA       float64 57.34
# Attributes:
#     Numerator:    Echo
#     Denominator:  Bravo

# %% [markdown]
# This can be better visualized using the `LCIA.dist_compare()` method, which plots the paired distribution of both concepts.

# %%
echo.dist_compare(bravo, pathway='MP', save=False)

# %%
echo.dist_compare(bravo, pathway='EP', save=True)
# Out:
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:679: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   f.savefig('.\\Outputs\\' + name + '.pdf', bbox_inches='tight', papertype='A4')

# %%
echo.dist('EP', save=True)
# Out:
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:540: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.savefig('.\\Outputs\\' + name + 'dist.pdf', bbox_inches='tight', papertype='A3')

# %%
bravo.dist2('EP', save=True)
# Out:
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:591: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.savefig('.\\Outputs\\' + name + 'dist.pdf', bbox_inches='tight', papertype='A3')

# %%
echo.bar('MP', subphase=False, save=True, palette='deep')
# Out:
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:647: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.savefig('.\\Outputs\\' + name + 'bar.pdf', bbox_inches='tight', papertype='A3')

# %%
echo.square(save=True)
# Out:
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')
# C:\Users\Parolin\Documents\Projects\AEco\Scripts\Tools.py:671: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   pdf.savefig(bbox_inches='tight', papertype='A4')

# %%
CTV_teste = echo.CTV.to_array()

# %%
CTV_avg = CTV_teste.mean(dim="variable").compute()

# %%
CTV_avg.sortby(CTV_avg, ascending=False)
# Out:
# <xarray.DataArray 'stack-961c04cb9db7f9ae4b9537ed8528666d' (Parameters: 75)>
# array([5.69e+01, 2.80e+01, 6.18e+00, 1.44e+00, 7.47e-01, 7.25e-01,
#        6.27e-01, 4.46e-01, 3.66e-01, 3.48e-01, 2.93e-01, 2.67e-01,
#        2.64e-01, 2.16e-01, 1.92e-01, 1.69e-01, 1.58e-01, 1.43e-01,
#        1.41e-01, 1.38e-01, 1.34e-01, 1.31e-01, 1.28e-01, 1.19e-01,
#        1.16e-01, 1.14e-01, 1.09e-01, 9.58e-02, 9.06e-02, 8.98e-02,
#        8.22e-02, 7.66e-02, 7.14e-02, 6.31e-02, 5.80e-02, 5.71e-02,
#        5.46e-02, 4.64e-02, 4.55e-02, 4.52e-02, 4.11e-02, 3.50e-02,
#        3.49e-02, 3.34e-02, 3.25e-02, 3.23e-02, 2.93e-02, 2.72e-02,
#        2.68e-02, 2.66e-02, 2.16e-02, 1.99e-02, 1.72e-02, 1.66e-02,
#        1.56e-02, 1.40e-02, 1.22e-02, 1.14e-02, 9.73e-03, 8.27e-03,
#        7.20e-03, 4.06e-03, 2.00e-03, 1.65e-03, 1.27e-03, 0.00e+00,
#        0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#        0.00e+00, 0.00e+00, 0.00e+00])
# Coordinates:
#   * Parameters  (Parameters) object 'd_f' 'FH' ... 'prototypes' 'payload'
